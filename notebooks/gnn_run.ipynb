# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd drive/MyDrive/graph-fake-news-detection

# %%
# !python -m src.main --dataset politifact --feature bert
# !python -m src.main --dataset gossipcop --feature bert

# %%
# UPFD-SAGE
# !python -u -m src.models.gnn --model 'sage' --feature 'bert' --epochs 30 --lr 0.01 --nhid 128 --batch_size 128 --dataset 'politifact' --multi_gpu False --concat True

# %%
# UPFD-SAGE
# !python -u -m src.models.gnn --model 'sage' --feature 'bert' --epochs 80 --lr 0.001 --nhid 128 --batch_size 128 --dataset 'gossipcop' --multi_gpu False --concat True

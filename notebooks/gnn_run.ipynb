# %%
# UPFD-GCN
# !python -u src/models/gnn.py --model 'gcn' --feature 'spacy' --epochs 60 --lr 0.001 --nhid 128 --batch_size 128 --dataset 'politifact' --multi_gpu True --concat True &&

# %%
# UPFD-GAT
# !python -u src/models/gnn.py --model 'gat' --feature 'bert' --epochs 50 --lr 0.001 --nhid 128 --batch_size 128 --dataset 'politifact' --multi_gpu True --concat True &&

# %%
# UPFD-SAGE
# !python -u src/models/gnn.py --model 'sage' --feature 'bert' --epochs 30 --lr 0.01 --nhid 128 --batch_size 128 --dataset 'politifact' --multi_gpu True --concat True &&
